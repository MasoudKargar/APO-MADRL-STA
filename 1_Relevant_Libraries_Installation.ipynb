# %% [markdown]
# # Asset Portfolio Management using Deep Reinforcement Learning
# ---

# %% [markdown]
# ## 1.0 Load and Install Relevant Libraries and Packages
# ----
#
# * We install the relevant Libraries using the FinRL Library
# * We further check that all the required Libraries are installed and if not we use !pip install to install them

# %% [markdown]
# ### 1.1 Install Packages through FinRL Library

# %%
## install finrl library if not installed

import pkg_resources
import pip
installedPackages = {pkg.key for pkg in pkg_resources.working_set} # list of installed packages

if 'finrl' not in installedPackages:
    # %pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git #clone the FinRL library to install required packages
# Out:
# C:\Users\nice\AppData\Local\Temp\ipykernel_16580\930650319.py:3: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources

# %% [markdown]
# ----
# ### 1.2. Check if the additional Required packages are present. If not, install them
#
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio
# * ta
# * PyPortfolioOpt

# %%
required = {'yfinance', 'pandas','numpy', 'matplotlib', 'stockstats','stable-baselines',
            'gym','tensorflow','pyfolio', 'ta', 'PyPortfolioOpt'}
missing = required - installedPackages
if missing:
    # %pip install yfinance
    # %pip install pandas
    # %pip install numpy
    # %pip install matplotlib
    # %pip install stockstats
    # %pip install gym
    # %pip install tensorflow
    # %pip install git+https://github.com/quantopian/pyfolio
    # %pip install ta
    # %pip install PyPortfolioOpt
# Out:
# Requirement already satisfied: yfinance in d:\users\nice\anaconda3\envs\rein\lib\site-packages (0.2.38)
# Requirement already satisfied: pandas>=1.3.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from yfinance) (5.2.1)
# Requirement already satisfied: appdirs>=1.4.4 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from yfinance) (3.17.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from requests>=2.31->yfinance) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from requests>=2.31->yfinance) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in d:\users\nice\anaconda3\envs\rein\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in d:\users\nice\anaconda3\envs\rein\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in d:\users\nice\anaconda3\envs\rein\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: stockstats in d:\users\nice\anaconda3\envs\rein\lib\site-packages (0.5.4)
# Requirement already satisfied: pandas>=0.24.2 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from stockstats) (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas>=0.24.2->stockstats) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas>=0.24.2->stockstats) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas>=0.24.2->stockstats) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas>=0.24.2->stockstats) (2024.1)
# Requirement already satisfied: six>=1.5 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->stockstats) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gym in d:\users\nice\anaconda3\envs\rein\lib\site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from gym) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from gym) (3.0.0)
# Requirement already satisfied: gym-notices>=0.0.4 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from gym) (0.0.8)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow in d:\users\nice\anaconda3\envs\rein\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.25.3)
# Requirement already satisfied: setuptools in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.62.2)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/quantopian/pyfolio
#   Cloning https://github.com/quantopian/pyfolio to c:\users\nice\appdata\local\temp\pip-req-build-smk8e2po
#   Resolved https://github.com/quantopian/pyfolio to commit 4b901f6d73aa02ceb6d04b7d83502e5c6f2e81aa
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: ipython>=3.2.3 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pyfolio==0.9.2+75.g4b901f6) (8.12.0)
# Requirement already satisfied: matplotlib>=1.4.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pyfolio==0.9.2+75.g4b901f6) (3.8.4)
# Requirement already satisfied: numpy>=1.11.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pyfolio==0.9.2+75.g4b901f6) (1.26.4)
# Requirement already satisfied: pandas>=0.18.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pyfolio==0.9.2+75.g4b901f6) (2.2.2)
# Requirement already satisfied: pytz>=2014.10 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pyfolio==0.9.2+75.g4b901f6) (2024.1)
# Requirement already satisfied: scipy>=0.14.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pyfolio==0.9.2+75.g4b901f6) (1.12.0)
# Requirement already satisfied: scikit-learn>=0.16.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pyfolio==0.9.2+75.g4b901f6) (1.4.2)
# Requirement already satisfied: seaborn>=0.7.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pyfolio==0.9.2+75.g4b901f6) (0.13.2)
# Requirement already satisfied: empyrical>=0.5.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pyfolio==0.9.2+75.g4b901f6) (0.5.5)
# Requirement already satisfied: pandas-datareader>=0.2 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from empyrical>=0.5.0->pyfolio==0.9.2+75.g4b901f6) (0.10.0)
# Requirement already satisfied: backcall in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from ipython>=3.2.3->pyfolio==0.9.2+75.g4b901f6) (0.2.0)
# Requirement already satisfied: decorator in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from ipython>=3.2.3->pyfolio==0.9.2+75.g4b901f6) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from ipython>=3.2.3->pyfolio==0.9.2+75.g4b901f6) (0.19.1)
# Requirement already satisfied: matplotlib-inline in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from ipython>=3.2.3->pyfolio==0.9.2+75.g4b901f6) (0.1.7)
# Requirement already satisfied: pickleshare in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from ipython>=3.2.3->pyfolio==0.9.2+75.g4b901f6) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from ipython>=3.2.3->pyfolio==0.9.2+75.g4b901f6) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from ipython>=3.2.3->pyfolio==0.9.2+75.g4b901f6) (2.17.2)
# Requirement already satisfied: stack-data in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from ipython>=3.2.3->pyfolio==0.9.2+75.g4b901f6) (0.6.3)
# Requirement already satisfied: traitlets>=5 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from ipython>=3.2.3->pyfolio==0.9.2+75.g4b901f6) (5.14.3)
# Requirement already satisfied: colorama in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from ipython>=3.2.3->pyfolio==0.9.2+75.g4b901f6) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from matplotlib>=1.4.0->pyfolio==0.9.2+75.g4b901f6) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from matplotlib>=1.4.0->pyfolio==0.9.2+75.g4b901f6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from matplotlib>=1.4.0->pyfolio==0.9.2+75.g4b901f6) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from matplotlib>=1.4.0->pyfolio==0.9.2+75.g4b901f6) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from matplotlib>=1.4.0->pyfolio==0.9.2+75.g4b901f6) (23.2)
# Requirement already satisfied: pillow>=8 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from matplotlib>=1.4.0->pyfolio==0.9.2+75.g4b901f6) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from matplotlib>=1.4.0->pyfolio==0.9.2+75.g4b901f6) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from matplotlib>=1.4.0->pyfolio==0.9.2+75.g4b901f6) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas>=0.18.1->pyfolio==0.9.2+75.g4b901f6) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from scikit-learn>=0.16.1->pyfolio==0.9.2+75.g4b901f6) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from scikit-learn>=0.16.1->pyfolio==0.9.2+75.g4b901f6) (3.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio==0.9.2+75.g4b901f6) (0.8.4)
# Requirement already satisfied: lxml in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio==0.9.2+75.g4b901f6) (5.2.1)
# Requirement already satisfied: requests>=2.19.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio==0.9.2+75.g4b901f6) (2.31.0)
# Requirement already satisfied: wcwidth in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=3.2.3->pyfolio==0.9.2+75.g4b901f6) (0.2.13)
# Requirement already satisfied: six>=1.5 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->pyfolio==0.9.2+75.g4b901f6) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from stack-data->ipython>=3.2.3->pyfolio==0.9.2+75.g4b901f6) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from stack-data->ipython>=3.2.3->pyfolio==0.9.2+75.g4b901f6) (2.4.1)
# Requirement already satisfied: pure-eval in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from stack-data->ipython>=3.2.3->pyfolio==0.9.2+75.g4b901f6) (0.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio==0.9.2+75.g4b901f6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio==0.9.2+75.g4b901f6) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio==0.9.2+75.g4b901f6) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio==0.9.2+75.g4b901f6) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/quantopian/pyfolio 'C:\Users\nice\AppData\Local\Temp\pip-req-build-smk8e2po'
# Requirement already satisfied: ta in d:\users\nice\anaconda3\envs\rein\lib\site-packages (0.11.0)
# Requirement already satisfied: numpy in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from ta) (1.26.4)
# Requirement already satisfied: pandas in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from ta) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas->ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas->ta) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas->ta) (2024.1)
# Requirement already satisfied: six>=1.5 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from python-dateutil>=2.8.2->pandas->ta) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: PyPortfolioOpt in d:\users\nice\anaconda3\envs\rein\lib\site-packages (1.5.5)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from PyPortfolioOpt) (1.4.3)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from PyPortfolioOpt) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from PyPortfolioOpt) (2.2.2)
# Requirement already satisfied: scipy<2.0,>=1.3 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from PyPortfolioOpt) (1.12.0)
# Requirement already satisfied: osqp>=0.6.2 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (0.6.4)
# Requirement already satisfied: ecos>=2 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (2.0.13)
# Requirement already satisfied: clarabel>=0.5.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (0.7.1)
# Requirement already satisfied: scs>=3.0 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (3.2.4.post1)
# Requirement already satisfied: pybind11 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (2.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas>=0.19->PyPortfolioOpt) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas>=0.19->PyPortfolioOpt) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from pandas>=0.19->PyPortfolioOpt) (2024.1)
# Requirement already satisfied: qdldl in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from osqp>=0.6.2->cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (0.1.7.post2)
# Requirement already satisfied: six>=1.5 in d:\users\nice\anaconda3\envs\rein\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.19->PyPortfolioOpt) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
